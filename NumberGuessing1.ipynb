# %% [markdown]
# <a href="https://colab.research.google.com/github/bindhupriyar2020/Python-practice/blob/main/NumberGuessing1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Number guessing game
import random
num=random.randint(1,100)
print("Enter your guess between 1 to 100")
while True:
  guess=int(input())
  if(guess<num):
    print("Try higher")
  elif(guess>num):
    print("Try lower")
  elif(guess==num):
    print("Your guess is correct!!")
    break
  else:
    print("Your guess must be between 1 to 100")
# Out:
# Enter your guess between 1 to 100
# 67
# Try lower
# 45
# Try lower
# 32
# Try lower
# 21
# Try higher
# 25
# Try higher
# 27
# Try higher
# 29
# Try lower
# 28
# Your guess is correct!!
